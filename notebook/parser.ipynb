# %%
# %load_ext autoreload
# %autoreload 2
import os
from pathlib import Path

print(Path().cwd())
os.chdir(Path().cwd().parent)
print(Path().cwd())
# Out:
# c:\0_Main\2_Quantitative_ultrasound\2_github\BSC\notebook
# c:\0_Main\2_Quantitative_ultrasound\2_github\BSC

# %% [markdown]
# ### Tar unpacker

# %%
from scr.clarius.main import unpack_clarius_data

# For multiple samples (default mode)
unpacker = unpack_clarius_data("data/samples")
# Out:
# 2025-07-09 11:12:12,228 - INFO - Starting Clarius data unpacking process in multiple_samples mode
# 2025-07-09 11:12:12,231 - INFO - Target path: data/samples
# 2025-07-09 11:12:12,231 - INFO - Cleaning up existing extracted folders...
# 2025-07-09 11:12:12,235 - INFO - Found 12 extracted folder(s) to clean up
# 2025-07-09 11:12:12,256 - INFO - Deleted: data\samples\UKDCEUS030\raw_0_0_extracted
# 2025-07-09 11:12:12,262 - INFO - Deleted: data\samples\UKDCEUS030\raw_0_1_extracted
# 2025-07-09 11:12:12,271 - INFO - Deleted: data\samples\UKDCEUS030\raw_0_2_extracted
# 2025-07-09 11:12:12,276 - INFO - Deleted: data\samples\UKDCEUS030\raw_0_3_extracted
# 2025-07-09 11:12:12,295 - INFO - Deleted: data\samples\UKDCEUS034\raw_0_0_extracted
# 2025-07-09 11:12:12,301 - INFO - Deleted: data\samples\UKDCEUS034\raw_0_1_extracted
# 2025-07-09 11:12:12,314 - INFO - Deleted: data\samples\UKDCEUS034\raw_0_2_extracted
# ...
